# %%
# %matplotlib inline

# %%
import nbodykit.lab as nlab
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
help(nlab.BinaryCatalog)
# Out:
# Help on class BinaryCatalog in module abc:
#
# class BinaryCatalog(nbodykit.source.catalog.file.FileCatalogBase)
#  |  A catalog source created using :class:`io.BinaryFile` to read data from disk
#  |
#  |  Method resolution order:
#  |      BinaryCatalog
#  |      nbodykit.source.catalog.file.FileCatalogBase
#  |      nbodykit.base.catalog.CatalogSource
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Parameters
#  |      ----------
#  |      path : str
#  |          the name of the binary file to load
#  |      dtype : numpy.dtype or list of tuples
#  |          the dtypes of the columns to load; this should be either a ``numpy.dtype``
#  |          or be able to be converted to one via a :func:`numpy.dtype` call
#  |      offsets : dict, optional
#  |          a dictionay specifying the byte offsets of each column in the binary
#  |          file; if not supplied, the offsets are inferred from the dtype size
# ...

# %%
halo_type = np.dtype([("gid",np.int64),("N",np.int64),("x",np.float32,3),("v",np.float32,3),("sigma_v",np.float32,3),
                      ("r25",np.float32),("r50",np.float32),("r75",np.float32),("r90",np.float32),
                      ("vcirc_max",np.float32),("rvcirc_max",np.float32),
                      ("pf_start",np.int64),("pf_np",np.int64)])

# %%
cat = nlab.BinaryCatalog('/Users/ding/Downloads/halos_1.field', dtype=halo_type)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-55a6f0d506a3> in <module>()
# ----> 1 cat = nlab.BinaryCatalog('/Users/ding/Downloads/halos_1.field', dtype=halo_type)
#
# ~/miniconda3/lib/python3.6/site-packages/nbodykit/source/catalog/file.py in __init__(self, *args, **kwargs)
#     106         use_cache = kwargs.pop('use_cache', False)
#     107         attrs = kwargs.pop('attrs', {})
# --> 108         FileCatalogBase.__init__(self, filetype=filetype, args=args, kwargs=kwargs)
#     109         self.attrs.update(attrs)
#     110
#
# ~/miniconda3/lib/python3.6/site-packages/nbodykit/__init__.py in wrapped(*args, **kwargs)
#      21             if kwargs['comm'] is None:
#      22                 kwargs['comm'] = CurrentMPIComm.get()
# ---> 23             return func(*args, **kwargs)
#      24         return wrapped
#      25
#
# ...
